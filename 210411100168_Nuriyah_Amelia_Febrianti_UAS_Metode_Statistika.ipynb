# %% [markdown]
# Nama : Nuriyah Amelia Febrianti
#
# NIM : 210411100168
#
# Mata Kuliah : Metode Statistika
#
# No. WhatsApp : 085707077441

# %% [markdown]
# #Estimasi Rata-rata

# %% [markdown]
# Interval estimasi adalah selompok nilai statistik sampel dalam intervaltertentu yang dapat digunakan untuk melakukan estimasi terhadap parameter populasi dengan harapan bahwa nilai parameter populasi terletak didalam intervaltersebut (Budiarto, 2001, p. 162.
#
# Rumus :
# Rata-rata (xbar)-t(a/2) x s/√𝑛 < 𝜇 < Rata-rata (xbar) + t(a/2) x s/√𝑛
#
# xbar = rata-rata s = standard deviasi n = jumlah sampel

# %% [markdown]
# #Standart Deviasi

# %% [markdown]
# Standar deviasi yaitu nilai statistik yang dimanfaatkan untuk menentukan bagaimana sebaran data dalam sampel, serta seberapa dekat titik data individu ke mean ataupun rata-rata nilai sampel.
#
# Cara Menghitung Standar Deviasi
# Rumus :
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Skewness

# %% [markdown]
# Skewness merupakan ukuran asimetri distribusi probabilitas variabel acak bernilai nyata.
#
# > Kecondongan Negatif
#
# Data lebih terkonsentrasi di sebelah kanan gambar seperti yang Anda lihat di bawah. Jadi ada ekor yang panjang di sisi kiri. Ini juga disebut miring kiri atau ekor kiri.
#
# > Kecondongan Positif
#
# Data lebih terkonsentrasi di sebelah kiri gambar seperti yang Anda lihat di bawah. Jadi ada ekor yang panjang di sisi kanan. Ini juga disebut miring kanan atau ekor kanan.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Kurtosis

# %% [markdown]
# 'Kurtosis' adalah ukuran 'tailedness' dari distribusi probabilitas variabel acak bernilai nyata. Ini umumnya digunakan untuk mengidentifikasi outlier (nilai ekstrim) dalam dataset yang diberikan. Karena digunakan untuk mengidentifikasi pencilan, nilai ekstrim di kedua ujung ekor digunakan untuk analisis.
#
# Cara menafsirkan Kurtosis :
#
# > Mesokurtic (Kurtosis = 3) - Distribusi ini menunjukkan kurtosis 3 mendekati nol. Distribusi nilai ekstrim (pencilan) mirip dengan distribusi normal.
#
# > Leptokurtik (Kurtosis> 3) - Distribusi ini menunjukkan kurtosis yang lebih besar daripada mesokurtik. Puncaknya lebih tinggi dan lebih tajam dari Mesokurtic. Ini menunjukkan ekor yang berat di kedua sisi yang menunjukkan pencilan yang besar. Dalam dunia investasi, leptokurtic distribution adalah investasi yang berisiko tinggi.
#
# > Platykurtic (Kurtosis <3) - Distribusi ini menunjukkan kurtosis yang lebih rendah daripada mesokurtic. Puncaknya lebih rendah dan lebih luas dari Mesokurtic. Ini menunjukkan ekor datar di kedua sisi yang menunjukkan pencilan kecil. Dalam dunia investasi, distribusi platykurtic berarti investasi berisiko rendah.
#
# ![image.png](data:image/png;base64,...)

# %%
#estimasi rata-rata
import math

n=math.sqrt(10)
s=7.50
ta=3.250
xbar=53.9

hasil = xbar - ta*s/n, xbar + ta*s/n

print(hasil)
# Out:
# (46.19194820333958, 61.60805179666042)

# %%
#Standard Deviasi
def standar_deviasi(data) :
    jumlah=0
    for i in range (len(data)):
        jumlah+=data[i]
        
    rata_rata=jumlah/len(data)
    sigma=0
    for i in range (len(data)):
        hitung=(data[i]-rata_rata)**2
        sigma+=hitung
    pembagianN=sigma/len(data)
    cariStandar_Deviasi=pembagianN**0.5
    print("Standar Deviasi adalah: ", cariStandar_Deviasi)
    
data=[50,58,43,64,47,50,56,47,60,64]
standar_deviasi(data)
# Out:
# Standar Deviasi adalah:  7.119691004531026

# %%
from scipy.stats import skew
data = [50,58,43,64,47,50,56,47,60,64]
skew(data)
# Out:
# 0.08176290963037283

# %%
from scipy.stats import kurtosis

data = [50,58,43,64,47,50,56,47,60,64]
kurtosis(data)
# Out:
# -1.380579722068635

# %% [markdown]
# #KNN Regresi

# %% [markdown]
# K-Nearest Neighbor merupakan metode Supervised Learning untuk mengelompokkan data pembelajaran terhadap objek dengan berdasarkan tetangga terdekat atau jarak yang paling dekat dengan objek . Tujuan dari Algoritma ini yaitu untuk mengelompokkan objek baru berdasarkan atribut dan sample-sample (Training Sample)
#
# Algoritma k- Nearest Neighbor menggunakan klasifikasi ketetanggaan (neighbor) sebagai nilai prediksi dari query instance yang baru. Algoritma ini sederhana, bekerja berdasarkan jarak terpendek dari query instance ke training sample untuk menentukan ketetanggaannya
#
# Kelebihan Algoritma K-Nearest Neighbor Lebih efektif pada data latihnya besar Mudah dipahami dan di Implementasikan Non-linear Karena algoritma K-NN bersifat non-parametik. Menghasilkan data yang lebih akurat Kekurangan Algoritma K-Nearest Neighbor Harus menentukan parameter K (jumlah tetangga terdekat) Sensitif terhadap data outlier Tingginya nilai komputasi Sensitif terhadap perbedaan rentang variabel dan dimensionalitas Sensitif terhadap dimensionalitas yang tinggi.

# %% [markdown]
# Tahapan metode k-Nearest Neighbor :
#
# >	Menentukan nilai K = 3
#
# >	Menghitung jarak antara data uji dengan data latih
#
# > Mengurutkan jarak dari yang terkecil hingga terbesar
#
# > Mengambil data sebanyak K tetangga terdekat
#
# > Menghitung rata-rata dari K tetangga terdekat
#
# Pendekatan Algoritma k-Nearest Neighbor algoritma knn adalah algoritma pembelajaran instance based yang paling banyak digunakan. algoritma knn ini algoritma yang paling sederhana dari algoritma yang lain nya.
#
# Instance merupakan titik dalam ruang n-dimensi dan mendeskripsikan tetangga (neighbor) dalam hal jarak ( Euclidean dalam ruang-R) k merupakan jumlah dari tetangga terdekat (neighbor) k = 1 disebut aturan klasifikasi tetangga terdekat banyak nya jumlah k lebih baik adalah angka ganjil seperti (1, 2, 3, …), untuk menghindari adanya ikatan atau hubungan

# %%
import math
Wi = 1
a = 49
b = 46
Wi2 = 3

hasil = (Wi*a+Wi*a+Wi*b)/Wi2

print(hasil)
# Out:
# 48.0

# %% [markdown]
# #Selang Kepercayaan

# %% [markdown]
# Selang kepercayaan (confidence interval) merupakan metode digunakan untuk memperkirakan parameter populasi berdasarkan sampel menggunakan metode statistik tertentu dalam sebuah rentang tertentu.
#
# Tujuan menggunakan interval kepercayaan adalah memiliki margin kesalahan sekecil mungkin. Semakin sempit interval, semakin akurat nilai statistik yang kita gunakan. Seperti yang kita tahu, margin of error bentuk toleransi yang mungkin terjadi dalam pengujian statistik. Pada dasarnya, sampel diambil secara acak untuk menghasilkan nilai yang dapat mewakili parameter. Tapi, pengukurannya akan berbeda jika Anda menggunakan sampel lain yang diambil secara acak. Hal ini akan menyebabkan perhitungan yang berbeda.
#
# Oleh karena itu, selang kepercayaan adalah solusi untuk memastikan bahwa statistik yang kita hasilkan akurat dalam rentang nilai tertentu (yang merupakan margin kesalahan) dan dapat menggambarkan populasi dengan baik.

# %%
import numpy as np
from scipy import stats

# %%
a = 2.6
b = 1.96
c = 0.05

hasil = a - b*c, a + b*c
print(hasil)
# Out:
# (2.5020000000000002, 2.698)
